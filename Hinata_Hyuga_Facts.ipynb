# %%
# !pip install beautifulsoup4
# !pip install pandas as pd
# !pip install requests
# !pip install lxml
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 16.3 MB/s eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re
import random
import time
import threading
import queue
import IPython
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Define the URL and headers
url = "https://gamerant.com/naruto-hinata-relationship/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Fetch the page
response = requests.get(url, headers=headers)
response.raise_for_status()

# Parse the HTML content
tree = html.fromstring(response.content)

# Use XPath to locate the first and second sections
first_section_xpath = '//*[@id="the-red-scarf-is-the-red-thread-of-fate"]'
second_section_xpath = '//*[@id="adsninja-ad-zone-div-gpt-ad-1535570269372-ccr-REPEAT4"]'

first_section = tree.xpath(first_section_xpath)[0]
second_section = tree.xpath(second_section_xpath)[0]

# Get all <p> tags between the First and Second sections
hinata_1 = []
current_element = first_section.getnext()

while current_element is not None and current_element != second_section:
    if current_element.tag == 'p':
        text = current_element.text_content().strip()
        if text:
            # Remove all occurrences of [x] where x is any number
            text = re.sub(r'\[\d+\]', '', text)
            sentences = sent_tokenize(text)
            for sentence in sentences:
                hinata_1.append([sentence])
    current_element = current_element.getnext()

# Convert the list to a DataFrame
hinata_bg_df = pd.DataFrame(hinata_1)

# Save the DataFrame to a CSV file
hinata_bg_df.to_csv('hinata_hyuga_1.csv', index=False)

# Display the DataFrame
hinata_bg_df
# Out:
#                                                    0
# 0  Yué Xiá Lǎorén (月下老人, the Old Man Under the Mo...
# 1  In the Japanese version, it is traditionally b...
# 2  In Naruto, two points regarding Hinata and Nar...
# 3  Because of its symbolism, it is as though the ...
# 4  Serving as a bridge and also tying in the stor...
# 5  While most people state that it makes no sense...
# 6  The red thread of fate also explains the appar...
# 7  Since it connects two lovers, they can recogni...

# %%
# Define the URL and headers
url = "https://www.thegamer.com/naruto-hinata-trivia-fans-wrong/?fbclid=IwZXh0bgNhZW0CMTEAAR0ifDK8vbJdv9x9NfzYTjiixJzrEx3pA2-1U5GeJ77CAl5iXqJD70vxKkM_aem_cNcWvgu2RC_EjZJJb2wbew"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Fetch the page
response = requests.get(url, headers=headers)
response.raise_for_status()

# Parse the HTML content
tree = html.fromstring(response.content)

# Use XPath to locate the first and second sections
first_section_xpath = '//*[@id="everybody-loves-sasuke"]'
second_section_xpath = '//*[@id="article-waypoint"]'

first_section = tree.xpath(first_section_xpath)[0]
second_section = tree.xpath(second_section_xpath)[0]

# Get all <p> tags between the First and Second sections
hinata_0 = []
current_element = first_section.getnext()

while current_element is not None and current_element != second_section:
    if current_element.tag == 'p':
        text = current_element.text_content().strip()
        if text:
            # Remove all occurrences of [x] where x is any number
            text = re.sub(r'\[\d+\]', '', text)
            sentences = sent_tokenize(text)
            for sentence in sentences:
                hinata_0.append([sentence])
    current_element = current_element.getnext()

# Convert the list to a DataFrame
hinata_bg_df = pd.DataFrame(hinata_0)

# Save the DataFrame to a CSV file
hinata_bg_df.to_csv('hinata_hyuga_0.csv', index=False)

# Display the DataFrame
hinata_bg_df
# Out:
#                                                      0
# 0    There's something about Sasuke that makes the ...
# 1    At the start of the series, Naruto tried to sh...
# 2    Hinata is the only female character who hasn't...
# 3    She has been kind to him, once giving her a be...
# 4    Hinata has always been fond of Naruto over eve...
# ..                                                 ...
# 128  Kishimoto originally had different plans for her.
# 129  He developed her as a character that would sup...
# 130  Kishimoto eventually changed his mind and deci...
# 131  In the Naruto Databook, her initial designs ha...
# 132  He eventually settled on styling her with ninj...
#
# [133 rows x 1 columns]

# %%
# Load the two CSV files into separate DataFrames
df_info_01 = pd.read_csv('hinata_hyuga_1.csv')
df_info_02 = pd.read_csv('hinata_hyuga_0.csv')


# Concatenate the DataFrames
df_combined = pd.concat([df_info_01, df_info_02], ignore_index=True)

# Save the combined DataFrame to a new CSV file
df_combined.to_csv('hinata_combined_info.csv', index=False)

# Print the combined DataFrame
df_combined
# Out:
#                                                      0
# 0    Yué Xiá Lǎorén (月下老人, the Old Man Under the Mo...
# 1    In the Japanese version, it is traditionally b...
# 2    In Naruto, two points regarding Hinata and Nar...
# 3    Because of its symbolism, it is as though the ...
# 4    Serving as a bridge and also tying in the stor...
# ..                                                 ...
# 136  Kishimoto originally had different plans for her.
# 137  He developed her as a character that would sup...
# 138  Kishimoto eventually changed his mind and deci...
# 139  In the Naruto Databook, her initial designs ha...
# 140  He eventually settled on styling her with ninj...
#
# [141 rows x 1 columns]

# %%
# Load the combined DataFrame
df_combined = pd.read_csv('hinata_combined_info.csv')

# Check for null values in the DataFrame
null_summary = df_combined.isnull().sum()

# Print the summary of null values
print("Summary of null values in each column:")
print(null_summary)
# Out:
# Summary of null values in each column:
# 0    0
# dtype: int64

# %%
df = pd.read_csv('hinata_combined_info.csv')

def clean_quote(quote):
    # Remove unwanted characters and fix encoding issues
    quote = re.sub(r'[^\x00-\x7F]+', '', quote)  # Remove non-ASCII characters
    quote = quote.replace('â€™', "'").replace('â€œ', '"').replace('â€', '"')
    quote = quote.replace('Å«', 'u')
    quote = quote.replace('"', '').replace("'", '')
    return quote.strip()

# Apply the cleaning function to the '0' column (assuming this is the correct column name)
df['0'] = df['0'].apply(clean_quote)

# Add a row number column
df.insert(0, 'Row Number', range(1, len(df) + 1))

# Save the cleaned DataFrame to a new CSV file without headers
df.to_csv('hinata_combined_info_cleaned.csv', index=False, header=False)
df.to_csv('hinata_combined_info_cleaned.txt', sep='\t', index=False, header=False)

# Load the cleaned file to remove the first row (headers)
cleaned_df = pd.read_csv('hinata_combined_info_cleaned.csv', header=None)

# Save the final cleaned DataFrame without headers
cleaned_df.to_csv('hinata_combined_info_cleaned_final.csv', index=False, header=False)
cleaned_df.to_csv('hinata_combined_info_cleaned_final.txt', sep='\t', index=False, header=False)

# Print the final cleaned DataFrame
print(cleaned_df)
# Out:
#        0                                                  1
# 0      1  Yu Xi Lorn (, the Old Man Under the Moon), the...
# 1      2  In the Japanese version, it is traditionally b...
# 2      3  In Naruto, two points regarding Hinata and Nar...
# 3      4  Because of its symbolism, it is as though the ...
# 4      5  Serving as a bridge and also tying in the stor...
# ..   ...                                                ...
# 136  137  Kishimoto originally had different plans for her.
# 137  138  He developed her as a character that would sup...
# 138  139  Kishimoto eventually changed his mind and deci...
# 139  140  In the Naruto Databook, her initial designs ha...
# 140  141  He eventually settled on styling her with ninj...
#
# [141 rows x 2 columns]
